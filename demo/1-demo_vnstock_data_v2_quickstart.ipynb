# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/vnstock-hq/vnstock_insider_guide/blob/main/demo/1-demo_vnstock_data_v2_quickstart.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Thiết lập

# %% [markdown]
# ## Google Colab

# %%
# !git clone https://github.com/vnstock-hq/vnstock_insider_guide
# %cd /content/vnstock_insider_guide/oneclick_installer
# !chmod +x linux_installer.run

# %%
# !./linux_installer.run

# %% [markdown]
# # Minh hoạ

# %% [markdown]
# ## 1. Thống kê giao dịch

# %%
from vnstock_data import Trading
trading = Trading(symbol='FPT')
START_DATE = '2024-01-02'
END_DATE = '2025-03-22'

# %% [markdown]
# ### Lịch sử giá

# %%
trading.price_history(start=START_DATE, end=END_DATE)
# Out:
# 2025-03-22 15:52:37 - vnstock_data.explorer.cafef.trading - INFO - Lịch sử giá:
# Mã CK: FPT. Số bản ghi hợp lệ: 300
#              open   high    low  close  adjusted_price  change_pct  \
# time
# 2025-03-21  125.0  129.0  125.0  128.0          128.00      0.0240
# 2025-03-20  124.6  126.8  124.5  125.0          125.00      0.0032
# 2025-03-19  130.1  130.6  123.5  124.6          124.60     -0.0415
# 2025-03-18  130.1  132.2  130.0  130.0          130.00      0.0000
# 2025-03-17  131.6  132.1  129.6  130.0          130.00     -0.0107
# ...           ...    ...    ...    ...             ...         ...
# 2024-01-08   97.4   98.3   97.1   97.3           83.45     -0.0010
# 2024-01-05   97.3   97.5   96.5   97.4           83.53      0.0021
# 2024-01-04   96.3   98.4   96.2   97.2           83.36      0.0093
# 2024-01-03   95.6   96.5   95.4   96.3           82.59      0.0042
# 2024-01-02   96.9   96.9   95.7   95.9           82.25     -0.0021
#
# ...

# %% [markdown]
# ### Thống kê đặt lệnh

# %%
trading.order_stats(start=START_DATE, end=END_DATE)
# Out:
# 2025-03-22 15:52:37 - vnstock_data.explorer.cafef.trading - INFO - Thống kê đặt lệnh:
# Mã CK: FPT. Số bản ghi hợp lệ: 298
#             buy_orders  sell_orders  buy_volume  sell_volume volume_diff  \
# time
# 2025-03-21       12215        11719    12135400     12266800    -131,400
# 2025-03-20       13899         8742    14561400     11804400   2,757,000
# 2025-03-19       36314        15221    28048200     26193600   1,854,600
# 2025-03-18       11750         6548    10752100      8310000   2,442,100
# 2025-03-17       15511         7327    11796600     10266200   1,530,400
# ...                ...          ...         ...          ...         ...
# 2024-01-08        1507         2972     2505500      3949800  -1,444,300
# 2024-01-05        1569         1901     2302100      2769400    -467,300
# 2024-01-04        2367         4246     4835700      6039300  -1,203,600
# 2024-01-03        2496         1737     2672800      2388400     284,400
# ...

# %% [markdown]
# ### Giao dịch nước ngoài

# %%
trading.foreign_trade(start=START_DATE, end=END_DATE)
# Out:
# 2025-03-22 15:52:38 - vnstock_data.explorer.cafef.trading - INFO - Lịch sử GD Nước ngoài:
# Mã CK: FPT. Số bản ghi hợp lệ: 297
#             fr_net_volume   fr_net_value  fr_buy_volume  fr_buy_value  \
# time
# 2025-03-21              0              0              0             0
# 2025-03-20              0              0              0             0
# 2025-03-19       -8496243 -1072042879200        1806878  228946830100
# 2025-03-18       -2405303  -314234133200         826788  108045848000
# 2025-03-17       -2079059  -271094441400         460436   60071848600
# ...                   ...            ...            ...           ...
# 2024-01-08         -11500    -1121480000              0             0
# 2024-01-05           2100      204330000           2100     204330000
# 2024-01-04            400       38520000            400      38520000
# 2024-01-03              0              0              0             0
# ...

# %% [markdown]
# ### Thống kê giao dịch tự doanh

# %%
trading.prop_trade(start=START_DATE, end=END_DATE)
# Out:
# 2025-03-22 15:52:38 - vnstock_data.explorer.cafef.trading - INFO - Lịch sử GD Tự Doanh:
# Mã CK: FPT. Số bản ghi hợp lệ: 302
#             prop_buy_volume  prop_sell_volume  prop_buy_value  prop_sell_value
# time
# 2025-03-21           333200            228800     42591580000      29176970000
# 2025-03-20           319900             86500     40077650000      10846730000
# 2025-03-19          2122200            430700    271717260000      53877040000
# 2025-03-18           213300            243300     27882370000      31780970000
# 2025-03-17           247300           1253700     32180280000     163207060000
# ...                     ...               ...             ...              ...
# 2024-01-08           202800            229400     19799970000      22366190000
# 2024-01-05           145600            206800     14135280000      20074670000
# 2024-01-04           766800            118700     74706660000      11583020000
# ...

# %% [markdown]
# ### Thống kê giao dịch nội bộ

# %%
trading.insider_deal(start='2024-01-02', end=END_DATE)
# Out:
# 2025-03-22 15:52:38 - vnstock_data.explorer.cafef.trading - INFO - Thống kê giao dịch Cổ Đông & Nội bộ:
# Mã CK: FPT. Số bản ghi hợp lệ: 13
#    symbol holder_id    transaction_man transaction_man_position  \
# 0     FPT         0     Bùi Quang Ngọc        Phó Chủ tịch HĐQT
# 1     FPT         0  Nguyễn Việt Thắng               Trưởng BKS
# 2     FPT         0    Đỗ Thị Ngọc Mai                      Con
# 3     FPT         0    Mai Thị Lan Anh        Công bố thông tin
# 4     FPT         0   Nguyễn Khải Hoàn           Thành viên BKS
# 5     FPT         0    Nguyễn Văn Khoa            Tổng Giám đốc
# 6     FPT         0     Phạm Minh Tuấn              Phó Tổng GĐ
# 7     FPT         0  Nguyễn Việt Thắng               Trưởng BKS
# 8     FPT         0  Nguyễn Thế Phương              Phó Tổng GĐ
# 9     FPT         0    Hoàng Hữu Chiến           Kế toán trưởng
# 10    FPT         0   Nguyễn Khải Hoàn           Thành viên BKS
# ...

# %% [markdown]
# ## 2. Giá lịch sử (đã điều chỉnh) & thống kê giao dịch trong ngày (intraday)

# %%
from vnstock_data import Quote

quote = Quote(symbol='REE')
quote.history(start='2000-07-28', end='2024-08-31', interval='1D')
# Out:
#            time   close    open    high     low   volume
# 0    2013-01-02   6.058   5.987   6.094   5.987   421680
# 1    2013-01-03   5.987   6.023   6.094   5.952   624970
# 2    2013-01-04   6.058   5.987   6.094   5.952   314290
# 3    2013-01-07   6.094   6.058   6.201   6.058   497270
# 4    2013-01-08   6.379   6.058   6.379   6.058  1872200
# ...         ...     ...     ...     ...     ...      ...
# 2904 2024-08-26  69.048  70.330  70.626  68.456   676600
# 2905 2024-08-27  67.667  68.653  69.048  67.470   692400
# 2906 2024-08-28  67.667  67.766  68.062  67.272   530200
# 2907 2024-08-29  68.062  67.568  68.062  67.470   328800
# 2908 2024-08-30  67.667  67.766  68.259  67.568   342100
#
# [2909 rows x 6 columns]

# %%
quote.intraday()
# Out:
#                    time  price  accumulated_val  accumulated_vol  volume  \
# 0   2025-03-21 09:15:03   71.9        970650000            13500   13500
# 1   2025-03-21 09:15:12   71.8        977830000            13600     100
# 2   2025-03-21 09:16:49   71.8        985010000            13700     100
# 3   2025-03-21 09:17:31   71.8        992190000            13800     100
# 4   2025-03-21 09:18:19   71.8        999370000            13900     100
# ..                  ...    ...              ...              ...     ...
# 721 2025-03-21 14:27:16   71.3      34940020000           487200     200
# 722 2025-03-21 14:27:16   71.3      34925760000           487000     100
# 723 2025-03-21 14:28:22   71.3      35011320000           488200    1000
# 724 2025-03-21 14:29:23   71.4      35018460000           488300     100
# 725 2025-03-21 14:45:04   71.5      36362660000           507100   18800
#
#     match_type
# 0          ATO
# 1         Sell
# 2          Buy
# 3         Sell
# ...

# %% [markdown]
# ## 3. Trạng thái niêm yết

# %%
from vnstock_data import Listing

Listing().all_symbols()
# Out:
#         code   type exchange    status  \
# 0        ENF    IFC    UPCOM  delisted
# 1       VEOF    IFC     HOSE    listed
# 2      VESAF    IFC     HOSE    listed
# 3      VMEEF    IFC     HOSE    listed
# 4     VFMVFA    IFC     HOSE  delisted
# ...      ...    ...      ...       ...
# 1944     LEC  STOCK     HOSE    listed
# 1945     SBC  STOCK     HOSE  delisted
# 1946     BID  STOCK     HOSE    listed
# 1947     GIL  STOCK     HOSE    listed
# 1948     CTD  STOCK     HOSE    listed
#
#                                            company_name  \
# 0     Quỹ Đầu tư Năng động Eastspring Investments Vi...
# 1               Công ty Cổ phần Quản lý Quỹ VinaCapital
# 2               Công ty Cổ phần Quản lý Quỹ VinaCapital
# 3               Công ty Cổ phần Quản lý Quỹ VinaCapital
# 4                        Quỹ Đầu tư năng động Việt Nam
# ...                                                 ...
# 1944   Công ty Cổ phần Bất động sản Điện lực Miền Trung
# ...

# %% [markdown]
# ## 4. Top cổ phiếu

# %%
from vnstock_data import TopStock
top = TopStock()

# %% [markdown]
# ### Top tăng giá

# %%
top.gainer()
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    HQC  VNINDEX        3.43  2025-03-21 15:59             0.22
# 1    LGL  VNINDEX        3.30  2025-03-21 15:59             0.21
# 2    VAF  VNINDEX       18.10  2025-03-21 15:59             1.15
# 3    HAR  VNINDEX        3.68  2025-03-21 15:59             0.22
# 4    FIR  VNINDEX        8.25  2025-03-21 15:59             0.35
# 5    DTA  VNINDEX        5.66  2025-03-21 15:59             0.22
# 6    THG  VNINDEX       60.50  2025-03-21 15:59             2.00
# 7    APG  VNINDEX       10.55  2025-03-21 15:59             0.30
# 8    VIC  VNINDEX       53.00  2025-03-21 15:59             1.50
# 9    JVC  VNINDEX        5.39  2025-03-21 15:59             0.14
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0             6.853583       5.484471e+10       4296475.0
# 1             6.796117       8.388990e+08        131470.0
# 2             6.784661       2.167000e+07         11295.0
# ...

# %% [markdown]
# ### Top giảm giá

# %%
top.loser()
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    ORS  VNINDEX       11.45  2025-03-21 15:59            -0.85
# 1    TCD  VNINDEX        2.62  2025-03-21 15:59            -0.18
# 2    BCG  VNINDEX        3.74  2025-03-21 15:59            -0.18
# 3    TMT  VNINDEX       14.00  2025-03-21 15:59            -0.50
# 4    VRC  VNINDEX       14.10  2025-03-21 15:59            -0.50
# 5    POW  VNINDEX       12.45  2025-03-21 15:59            -0.40
# 6    TPB  VNINDEX       14.75  2025-03-21 15:59            -0.45
# 7    VID  VNINDEX        5.21  2025-03-21 15:59            -0.14
# 8    YBM  VNINDEX       15.10  2025-03-21 15:59            -0.40
# 9    TYA  VNINDEX       17.15  2025-03-21 15:59            -0.45
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0            -6.910569       2.183817e+11      12638620.0
# 1            -6.428571       1.045368e+10       2820890.0
# 2            -4.591837       9.236037e+10      23129320.0
# ...

# %% [markdown]
# ### Top theo GTGD lớn nhất

# %%
top.value()
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    SHB  VNINDEX       11.75  2025-03-21 15:59             0.00
# 1    FPT  VNINDEX      128.00  2025-03-21 15:59             3.00
# 2    VHM  VNINDEX       48.25  2025-03-21 15:59             0.90
# 3    VND  VNINDEX       15.35  2025-03-21 15:59             0.20
# 4    TPB  VNINDEX       14.75  2025-03-21 15:59            -0.45
# 5    SSI  VNINDEX       26.60  2025-03-21 15:59             0.05
# 6    HPG  VNINDEX       27.15  2025-03-21 15:59             0.00
# 7    VCI  VNINDEX       39.10  2025-03-21 15:59            -0.10
# 8    VIC  VNINDEX       53.00  2025-03-21 15:59             1.50
# 9    MBB  VNINDEX       24.30  2025-03-21 15:59             0.05
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0             0.000000       8.834236e+11      40255260.0
# 1             2.400000       8.202042e+11       6297220.0
# 2             1.900739       6.590011e+11      11663385.0
# ...

# %% [markdown]
# ### Top theo KLGD

# %%
top.volume()
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    HAR  VNINDEX        3.68  2025-03-21 15:59             0.22
# 1    CKG  VNINDEX       20.00  2025-03-21 15:59             0.30
# 2    HQC  VNINDEX        3.43  2025-03-21 15:59             0.22
# 3    DLG  VNINDEX        2.10  2025-03-21 15:59            -0.02
# 4    NAB  VNINDEX       17.30  2025-03-21 15:59            -0.25
# 5    C32  VNINDEX       19.70  2025-03-21 15:59             0.00
# 6    BCE  VNINDEX       10.30  2025-03-21 15:59             0.00
# 7    VPI  VNINDEX       56.80  2025-03-21 15:59            -0.40
# 8    LGL  VNINDEX        3.30  2025-03-21 15:59             0.21
# 9    SJS  VNINDEX      101.00  2025-03-21 15:59             1.00
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0             6.358382       5.768113e+09        226545.0
# 1             1.522843       5.370485e+09         58490.0
# 2             6.853583       5.484471e+10       4296475.0
# ...

# %% [markdown]
# ### Top GD thoả thuận

# %%
top.deal()
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    OCB  VNINDEX       11.00  2025-03-21 15:59            -0.15
# 1    SJS  VNINDEX      101.00  2025-03-21 15:59             1.00
# 2    DBD  VNINDEX       58.00  2025-03-21 15:59            -0.20
# 3    CTF  VNINDEX       20.45  2025-03-21 15:59            -0.05
# 4    SSB  VNINDEX       19.85  2025-03-21 15:59             0.00
# 5    HVH  VNINDEX        9.55  2025-03-21 15:59             0.07
# 6    ACB  VNINDEX       26.10  2025-03-21 15:59            -0.15
# 7    NAB  VNINDEX       17.30  2025-03-21 15:59            -0.25
# 8    SIP  VNINDEX       90.10  2025-03-21 15:59             0.10
# 9    PET  VNINDEX       23.10  2025-03-21 15:59             0.10
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0            -1.345291       3.472276e+10       2791010.0
# 1             1.000000       4.301100e+09         22335.0
# 2            -0.343643       6.043190e+09        199585.0
# ...

# %% [markdown]
# ### Top NĐTNN mua ròng

# %%
top.foreign_buy(date='2024-08-16')
# Out:
#   symbol        date     net_value
# 0    MWG  2024-08-16  1.015998e+11
# 1    CTG  2024-08-16  6.709855e+10
# 2    DIG  2024-08-16  6.705117e+10
# 3    MSN  2024-08-16  6.318864e+10
# 4    VCI  2024-08-16  5.041683e+10
# 5    VND  2024-08-16  3.089996e+10
# 6    NVL  2024-08-16  3.054193e+10
# 7    DPM  2024-08-16  2.839805e+10
# 8    DGC  2024-08-16  2.769208e+10
# 9    FPT  2024-08-16  2.629880e+10

# %% [markdown]
# ### Top NĐTNN bán ròng

# %%
top.foreign_sell(date='2024-08-16')
# Out:
#      symbol        date     net_value
# 0       VHM  2024-08-16 -3.136147e+11
# 1       HPG  2024-08-16 -1.804457e+11
# 2       TCB  2024-08-16 -1.083005e+11
# 3       HSG  2024-08-16 -5.660693e+10
# 4       VPB  2024-08-16 -4.944804e+10
# 5  FUEVFVND  2024-08-16 -3.769779e+10
# 6       FRT  2024-08-16 -3.130877e+10
# 7       HDB  2024-08-16 -2.534124e+10
# 8       QNS  2024-08-16 -1.809028e+10
# 9       NLG  2024-08-16 -1.657578e+10

# %% [markdown]
# ## 5. Phân tích thị trường

# %%
from vnstock_data import Market

market = Market(index='VNINDEX')

# %%
market.pe()
# Out:
#                    pe
# reportDate
# 2020-03-23  10.443731
# 2020-03-24  10.329050
# 2020-03-25  10.812168
# 2020-03-26  10.873666
# 2020-03-27  10.903200
# ...               ...
# 2025-03-17  13.263778
# 2025-03-18  13.210796
# 2025-03-19  13.147344
# 2025-03-20  13.141230
# 2025-03-21  13.120329
#
# [1245 rows x 1 columns]

# %%
market.pb()
# Out:
#                   pb
# reportDate
# 2020-03-23  1.831608
# 2020-03-24  1.811600
# 2020-03-25  1.896378
# 2020-03-26  1.907164
# 2020-03-27  1.912355
# ...              ...
# 2025-03-17  1.715332
# 2025-03-18  1.708441
# 2025-03-19  1.700305
# 2025-03-20  1.699462
# 2025-03-21  1.696856
#
# [1245 rows x 1 columns]

# %%
market.evaluation()
# Out:
#                    pe        pb
# reportDate
# 2020-03-23  10.443731  1.831608
# 2020-03-24  10.329050  1.811600
# 2020-03-25  10.812168  1.896378
# 2020-03-26  10.873666  1.907164
# 2020-03-27  10.903200  1.912355
# ...               ...       ...
# 2025-03-17  13.263778  1.715332
# 2025-03-18  13.210796  1.708441
# 2025-03-19  13.147344  1.700305
# 2025-03-20  13.141230  1.699462
# 2025-03-21  13.120329  1.696856
#
# [1245 rows x 2 columns]

# %% [markdown]
# ## 6. Giá hàng hoá

# %%
from vnstock_data import CommodityPrice

# Khởi tạo đối tượng CommodityPrice với ngày mặc định
commodity = CommodityPrice(start="2022-01-03", end="2024-12-31")

# Lấy dữ liệu giá vàng
gold_vn = commodity.gold_vn()  # Giá vàng Việt Nam (mua vào)
print("Gold VN:\n", gold_vn)

gold_global = commodity.gold_global()  # Giá vàng thế giới
print("Gold Global:\n", gold_global)

# Lấy dữ liệu giá xăng
gas_vn = commodity.gas_vn()  # Giá xăng RON92
print("Gas VN:\n", gas_vn)

oil_crude = commodity.oil_crude()  # Giá dầu thô
print("Oil Crude:\n", oil_crude)

# Lấy dữ liệu khí thiên nhiên
gas_natural = commodity.gas_natural()  # Giá khí thiên nhiên
print("Gas Natural:\n", gas_natural)

# Lấy dữ liệu giá than
coke = commodity.coke()  # Giá than cốc
print("Coke:\n", coke)

# Lấy dữ liệu giá thép
steel_d10 = commodity.steel_d10()  # Giá thép D10
print("Steel D10:\n", steel_d10)

steel_hrc = commodity.steel_hrc()  # Giá thép HRC
print("Steel HRC:\n", steel_hrc)

# Lấy dữ liệu giá quặng sắt
iron_ore = commodity.iron_ore()  # Giá quặng sắt
print("Iron Ore:\n", iron_ore)

# Lấy dữ liệu giá phân bón
fertilizer_ure = commodity.fertilizer_ure()  # Giá phân ure
print("Fertilizer URE:\n", fertilizer_ure)

# Lấy dữ liệu giá nông sản
soybean = commodity.soybean()  # Giá đậu tương
print("Soybean:\n", soybean)

corn = commodity.corn()  # Giá ngô (bắp)
print("Corn:\n", corn)

sugar = commodity.sugar()  # Giá đường
print("Sugar:\n", sugar)

# Lấy dữ liệu giá heo hơi
pork_north_vn = commodity.pork_north_vn()  # Giá heo hơi miền Bắc Việt Nam
print("Pork North VN:\n", pork_north_vn)

pork_china = commodity.pork_china()  # Giá heo hơi Trung Quốc
print("Pork China:\n", pork_china)
# Out:
# Gold VN:
#                  buy     sell
# time
# 2022-01-03  60900.0  61600.0
# 2022-01-04  61000.0  61700.0
# 2022-01-05  60750.0  61450.0
# 2022-01-06  60900.0  61600.0
# 2022-01-09  60900.0  61650.0
# ...             ...      ...
# 2024-12-25  82300.0  84300.0
# 2024-12-26  82500.0  84500.0
# 2024-12-27  82700.0  84700.0
# 2024-12-28  82700.0  84700.0
# 2024-12-30  82500.0  84500.0
#
# [791 rows x 2 columns]
# Gold Global:
#                open    high     low   close    volume
# time
# 2022-01-03  1830.1  1833.0  1798.2  1800.1  168305.0
# 2022-01-04  1801.1  1817.2  1798.1  1814.6  167708.0
# 2022-01-05  1815.2  1830.7  1808.2  1825.1  173344.0
# 2022-01-06  1810.6  1811.6  1785.4  1789.2  238644.0
# 2022-01-07  1791.0  1798.4  1781.3  1797.4  238931.0
# ...            ...     ...     ...     ...       ...
# 2024-12-23  2639.1  2646.8  2623.2  2628.2  100814.0
# 2024-12-24  2629.4  2635.8  2624.2  2635.5   52221.0
# 2024-12-26  2638.0  2655.7  2634.1  2653.9   77712.0
# ...
