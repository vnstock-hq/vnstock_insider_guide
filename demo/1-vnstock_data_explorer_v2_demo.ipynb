# %% [markdown]
# <p>
#   <a href="https://codespaces.new/vnstock-hq/vnstock_insider_guide" target="_blank" style="display:inline-block; vertical-align:middle;">
#     <img src="https://img.shields.io/badge/Open%20in-GitHub%20Codespaces-blue?logo=github" alt="Open in GitHub Codespaces" style="height:20px; vertical-align:middle;">
#   </a>
#   <a href="https://colab.research.google.com/github/vnstock-hq/vnstock_insider_guide/blob/main/demo/1-vnstock_data_explorer_v2_demo.ipynb" target="_blank" style="display:inline-block; vertical-align:middle; margin-left:8px;">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" style="height:20px; vertical-align:middle;">
#   </a>
# </p>

# %% [markdown]
# # I. Cài đặt thư viện

# %% [markdown]
# ### Dành cho Google Colab & Github Codespace

# %% [markdown]
# **Đối với Github Codespace**
#
# 1. Mở Notebook với nút `Open in Codespace` ở đầu trang
# 2. Tạo Codespace mới để thử nghiệm Notebook Minh hoạ
#
# ![](http://vnstocks.com/images/vnstock-guide-github-codespace.png)
#
# 3. Mở Terminal bằng phím tắt Ctrl + ` (phím backtick dưới phím Esc) sau đó nhập các dòng lệnh bên dưới vào
#
# **Đối với Google Colab**
#
# Chạy ô lệnh bên dưới tại Notebook minh hoạ này trên dịch vụ [Google Colab](https://colab.research.google.com/)

# %%
# Tải file về và lưu với tên vnstock-cli-installer.run
# !wget https://vnstocks.com/files/vnstock-cli-installer.run
# Phân quyền và chạy cài đặt
# !chmod +x vnstock-cli-installer.run
# !./vnstock-cli-installer.run

# %% [markdown]
# **⚡ Lựa chọn nền tảng:**
# - **GitHub Codespaces** (Khuyến nghị): Môi trường đầy đủ, không cần cài đặt Python phức tạp và không bị chặn IP từ nguồn VCI.
# - **Google Colab**: Miễn phí với hỗ trợ lưu trữ trong Google Drive. Hiện tại đang bị nguồn VCI chặn IP nên một số tính năng không sử dụng được.

# %% [markdown]
# # II. Minh hoạ

# %% [markdown]
# ## 1. Thống kê giao dịch

# %%
from vnstock_data import Trading
trading = Trading(symbol='MSN', source='VCI')
START_DATE = '2024-01-02'
END_DATE = '2024-11-08'

# %% [markdown]
# ### Lịch sử giá

# %%
trading.price_history(start=START_DATE, end=END_DATE)
# Out:
#    trading_date    market_cap  total_shares  ceiling_price  floor_price  \
# 0    2024-11-08  1.039928e+14  1.438352e+09        78400.0      68200.0
# 1    2024-11-07  1.054312e+14  1.438352e+09        79300.0      69100.0
# 2    2024-11-06  1.067257e+14  1.438352e+09        78200.0      68000.0
# 3    2024-11-05  1.051435e+14  1.438352e+09        78300.0      68100.0
# 4    2024-11-04  1.052873e+14  1.438352e+09        79700.0      69300.0
# ..          ...           ...           ...            ...          ...
# 95   2024-06-26  1.064380e+14  1.438352e+09        79000.0      68800.0
# 96   2024-06-25  1.062942e+14  1.438352e+09        78800.0      68600.0
# 97   2024-06-24  1.060065e+14  1.438352e+09        81500.0      70900.0
# 98   2024-06-21  1.096024e+14  1.438352e+09        81100.0      70500.0
# 99   2024-06-20  1.090271e+14  1.438352e+09        80800.0      70400.0
#
#     reference_price     open    close  match_price  price_change  ...  \
# ...

# %% [markdown]
# ### Thống kê đặt lệnh

# %%
# trading.order_stats(start=START_DATE, end=END_DATE)

# %% [markdown]
# ### Giao dịch nước ngoài

# %%
trading.foreign_trade(start=START_DATE, end=END_DATE)
# Out:
#    trading_date  fr_buy_value_matched  fr_buy_volume_matched  \
# 0    2024-11-08          1.065098e+10               146711.0
# 1    2024-11-07          4.068370e+09                55000.0
# 2    2024-11-06          2.631442e+10               356400.0
# 3    2024-11-05          2.159033e+10               294193.0
# 4    2024-11-04          1.573124e+10               213500.0
# ..          ...                   ...                    ...
# 95   2024-06-26          6.965649e+10               947070.0
# 96   2024-06-25          7.854234e+10              1060800.0
# 97   2024-06-24          1.376264e+11              1847490.0
# 98   2024-06-21          6.399330e+10               835800.0
# 99   2024-06-20          8.404117e+10              1110080.0
#
#     fr_sell_value_matched  fr_sell_volume_matched  fr_buy_value_deal  \
# 0            1.432477e+11               1968006.0       0.000000e+00
# 1            9.707600e+10               1315540.0       7.450000e+09
# ...

# %% [markdown]
# ### Thống kê giao dịch tự doanh

# %%
trading.prop_trade(start=START_DATE, end=END_DATE)
# Out:
#    trading_date  total_buy_trade_volume  percent_buy_trade_volume  \
# 0    2024-11-08                280000.0                  0.035814
# 1    2024-11-07                 91200.0                  0.020004
# 2    2024-11-06                305800.0                  0.048767
# 3    2024-11-05                 54800.0                  0.010173
# 4    2024-11-04                437600.0                  0.043405
# ..          ...                     ...                       ...
# 95   2024-06-26                 85200.0                  0.023997
# 96   2024-06-25                380700.0                  0.034684
# 97   2024-06-24               1842400.0                  0.056328
# 98   2024-06-21                 58700.0                  0.014765
# 99   2024-06-20                429700.0                  0.103275
#
#     total_buy_trade_value  percent_buy_trade_value  total_sell_trade_volume  \
# 0            2.041137e+10                 0.035909                 184100.0
# ...

# %% [markdown]
# ### Thống kê giao dịch nội bộ

# %%
trading.insider_deal(start='2024-01-02', end=END_DATE)
# Out:
#             start_date            end_date         public_date  \
# 0  2025-07-30 00:00:00 2025-07-30 00:00:00 2025-07-31 00:00:00
# 1  2025-07-30 00:00:00 2025-07-30 00:00:00 2025-07-31 00:00:00
# 2  2025-07-30 00:00:00 2025-07-30 00:00:00 2025-07-31 00:00:00
# 3  2025-07-30 00:00:00 2025-07-30 00:00:00 2025-07-31 00:00:00
# 4  2025-07-30 00:00:00 2025-07-30 00:00:00 2025-07-31 00:00:00
# ..                 ...                 ...                 ...
# 81 2011-01-17 17:24:02 2011-05-13 17:24:02 2011-05-24 17:24:02
# 82 2011-02-08 17:11:13 2011-03-08 17:11:13 2011-04-05 17:11:13
# 83 2010-12-31 11:25:36 2010-12-31 11:25:36 2011-01-05 11:25:36
# 84 2011-01-04 11:19:23 2011-01-04 11:19:23 2011-01-05 11:19:23
# 85 2009-12-29 17:45:06 2009-12-29 17:45:06 2010-02-08 17:45:06
#
#     share_before_trade  share_after_trade  share_register  share_acquire  \
# 0             200068.0           355949.0        155881.0       155881.0
# ...

# %% [markdown]
# ### Bảng giá

# %%
trading = Trading(symbol='MSN', source='vci')
trading.price_board(symbols_list=['VCB','ACB','TCB','BID'], flatten_columns=True, drop_levels=[0])
# Out:
#   symbol  ceiling  floor  ref_price _stock_type exchange     trading_status  \
# 0    VCB    73900  64300      69100       STOCK      HSX  TRADING_ACTIVATED
# 1    ACB    29550  25750      27650       STOCK      HSX  TRADING_ACTIVATED
# 2    TCB    41650  36250      38950       STOCK      HSX  TRADING_ACTIVATED
# 3    BID    45750  39850      42800       STOCK      HSX  TRADING_ACTIVATED
#
#   security_status last_trading_date issue_date  ...  bid_2_price  \
# 0               N              None       None  ...        69200
# 1               N              None       None  ...        27500
# 2               N              None       None  ...        39100
# 3               N              None       None  ...        42700
#
#    bid_2_volume  bid_3_price bid_3_volume ask_1_price ask_1_volume  \
# 0         48200        69100        61700       69400         9900
# 1         61700        27450        29400       27600         7000
# ...

# %% [markdown]
# ## 2. Giá lịch sử (đã điều chỉnh) & thống kê giao dịch trong ngày (intraday)

# %% [markdown]
# ### VND

# %%
# Dữ liệu từ VND
from vnstock_data.explorer.vnd import Quote

quote = Quote(symbol='REE')
quote.history(start='2000-07-28', end='2024-08-31', interval='1D')
# Out:
#            time   close    open    high     low   volume
# 0    2013-01-02   6.058   5.987   6.094   5.987   421680
# 1    2013-01-03   5.987   6.023   6.094   5.952   624970
# 2    2013-01-04   6.058   5.987   6.094   5.952   314290
# 3    2013-01-07   6.094   6.058   6.201   6.058   497270
# 4    2013-01-08   6.379   6.058   6.379   6.058  1872200
# ...         ...     ...     ...     ...     ...      ...
# 2904 2024-08-26  69.048  70.330  70.626  68.456   676600
# 2905 2024-08-27  67.667  68.653  69.048  67.470   692400
# 2906 2024-08-28  67.667  67.766  68.062  67.272   530200
# 2907 2024-08-29  68.062  67.568  68.062  67.470   328800
# 2908 2024-08-30  67.667  67.766  68.259  67.568   342100
#
# [2909 rows x 6 columns]

# %%
quote.intraday()

# %% [markdown]
# ### VCI

# %% [markdown]
# Dữ liệu tại mục này tương đương hàm có trong Vnstock bản Public tuy nhiên được nâng cấp 10X giới hạn rate limit (số requests được phép trong một khung thời gian)

# %%
# Dữ liệu từ VCI

from vnstock_data.explorer.vci import Quote

quote = Quote(symbol='REE')
quote.history(start='2000-07-28', end='2024-08-31', interval='1D')
# Out:
#            time   open   high    low  close  volume
# 0    2000-07-28   0.53   0.53   0.53   0.53    1000
# 1    2000-07-31   0.54   0.54   0.54   0.54     300
# 2    2000-08-02   0.55   0.55   0.55   0.55     100
# 3    2000-08-04   0.56   0.56   0.56   0.56     200
# 4    2000-08-07   0.57   0.57   0.57   0.57    2800
# ...         ...    ...    ...    ...    ...     ...
# 5849 2024-08-26  70.33  70.63  68.46  69.05  678177
# 5850 2024-08-27  68.65  69.05  67.47  67.67  694135
# 5851 2024-08-28  67.77  68.06  67.27  67.67  531151
# 5852 2024-08-29  67.57  68.06  67.47  68.06  329921
# 5853 2024-08-30  67.77  68.26  67.57  67.67  342819
#
# [5854 rows x 6 columns]

# %%
# Dữ liệu từ VCI
quote.intraday()
# Out:
#                         time  price  volume match_type         id
# 0  2025-05-06 14:27:21+07:00   70.0     200       Sell  293924713
# 1  2025-05-06 14:27:31+07:00   70.0     500       Sell  293925417
# 2  2025-05-06 14:27:40+07:00   70.1     700        Buy  293926000
# 3  2025-05-06 14:27:40+07:00   70.1     300        Buy  293925999
# 4  2025-05-06 14:27:54+07:00   70.0    4300       Sell  293927012
# ..                       ...    ...     ...        ...        ...
# 95 2025-05-06 14:45:00+07:00   69.7     100        Buy  293948958
# 96 2025-05-06 14:45:00+07:00   69.7     200        Buy  293948959
# 97 2025-05-06 14:45:00+07:00   69.7    1000        Buy  293948960
# 98 2025-05-06 14:45:00+07:00   69.7     100        Buy  293948962
# 99 2025-05-06 14:45:00+07:00   69.7     500        Buy  293948937
#
# [100 rows x 5 columns]

# %% [markdown]
# ## 3. Báo cáo tài chính

# %% [markdown]
# #### VCI

# %% [markdown]
# Dữ liệu tại mục này tương đương hàm có trong Vnstock bản Public tuy nhiên được nâng cấp 10X giới hạn rate limit (số requests được phép trong một khung thời gian)

# %%
from vnstock_data.explorer.vci import Finance
# Khai báo tham số period một lần khi khởi tạo hoặc thay đổi khi gọi phương thức cụ thể, mặc định là 'quarter'
fin = Finance(symbol='VCI', period='quarter')

# %%
# Bỏ .head() để hiển thị toàn bộ dữ liệu
fin.balance_sheet(period='year', lang='vi').head()
# Out:
#     CP   Năm  TÀI SẢN NGẮN HẠN (đồng)  Tiền và tương đương tiền (đồng)  \
# 0  VCI  2024           26491835561026                    4743771932745
# 1  VCI  2023           17174448616966                     787897819240
# 2  VCI  2022           14157693071824                    3423501614803
# 3  VCI  2021           16568965942558                    1131748599533
# 4  VCI  2020            8312170798945                     642512983590
#
#    Giá trị thuần đầu tư ngắn hạn (đồng)  Các khoản phải thu ngắn hạn (đồng)  \
# 0                        21072524575199                        506858248065
# 1                        15097165308797                       1094491429414
# 2                        10562264962864                        120085485886
# 3                        14998113044339                        285206345277
# 4                         6697916243107                        221798617565
#
#    Hàng tồn kho ròng  Tài sản lưu động khác  TÀI SẢN DÀI HẠN (đồng)  \
# ...

# %%
# Bỏ .head() để hiển thị toàn bộ dữ liệu
fin.balance_sheet(period='quarter', lang='vi').head()
# Out:
#     CP   Năm  Kỳ  TÀI SẢN NGẮN HẠN (đồng)  Tiền và tương đương tiền (đồng)  \
# 0  VCI  2025   1           23620977742780                    2302263974886
# 1  VCI  2024   4           26491835561026                    4743771932745
# 2  VCI  2024   3           20322217963459                    2543516547760
# 3  VCI  2024   2           23009916452730                    3903157759657
# 4  VCI  2024   1           19458498860847                    1040594399692
#
#    Giá trị thuần đầu tư ngắn hạn (đồng)  Các khoản phải thu ngắn hạn (đồng)  \
# 0                        19710214115776                       1256719415203
# 1                        21072524575199                        506858248065
# 2                        17408880681428                        235746508338
# 3                        17775135464006                        931122579216
# 4                        17454154906730                        702530886335
#
# ...

# %%
# Bỏ .head() để hiển thị toàn bộ dữ liệu
fin.income_statement(period='year', lang='vi').head()
# Out:
#     CP   Năm  Doanh thu (đồng)  Tăng trưởng doanh thu (%)  \
# 0  VCI  2024     3695525335470                   0.494675
# 1  VCI  2023     2472460543397                  -0.216644
# 2  VCI  2022     3156242736345                  -0.148588
# 3  VCI  2021     3707068724492                   1.143320
# 4  VCI  2020     1729591590563                   0.122423
#
#    Lợi nhuận sau thuế của Cổ đông công ty mẹ (đồng)  \
# 0                                      910692113293
# 1                                      491904659394
# 2                                      868978185802
# 3                                     1498718375328
# 4                                      768912289421
#
#    Tăng trưởng lợi nhuận (%)  Doanh thu thuần  Giá vốn hàng bán  \
# 0                   0.851359    3695525335470    -1717402022529
# 1                  -0.433927    2472460543397    -1063597101525
# 2                  -0.420186    3156242736345    -1398531179478
# ...

# %%
# Bỏ .head() để hiển thị toàn bộ dữ liệu
fin.cash_flow(period='year', lang='vi').head()
# Out:
#     CP   Năm  Lãi/Lỗ ròng trước thuế  Khấu hao TSCĐ  Dự phòng RR tín dụng  \
# 0  VCI  2024           1089337104906    10751194638            4516800000
# 1  VCI  2023            570138640134     9679599271           11292000000
# 2  VCI  2022           1059738713385     9647191174                     0
# 3  VCI  2021           1850585393088     7496942452            -214202387
# 4  VCI  2020            951038957081    10634646105             -35400000
#
#    Lãi/Lỗ chênh lệch tỷ giá chưa thực hiện  Lãi/Lỗ từ hoạt động đầu tư  \
# 0                                        0                           0
# 1                                        0                           0
# 2                                        0                   154602984
# 3                                        0                           0
# 4                                        0                  -500000000
#
#    Thu nhập lãi  Thu lãi và cổ tức  \
# 0  764124674808      -8.608679e+10
# ...

# %%
# Bỏ .head() để hiển thị toàn bộ dữ liệu
fin.ratio(period='year', lang='vi', dropna=True).head()
# Out:
#   Meta          Chỉ tiêu cơ cấu nguồn vốn                           \
#     CP   Năm Kỳ          (Vay NH+DH)/VCSH   Nợ/VCSH TSCĐ / Vốn CSH
# 0  VCI  2024  5                  0.971382  1.054349       0.002879
# 1  VCI  2023  5                  1.218152  1.340876       0.003178
# 2  VCI  2022  5                  0.973942  1.192721       0.003617
# 3  VCI  2021  5                  0.972610  1.543047       0.002011
# 4  VCI  2020  5                  0.596293  0.853905       0.003181
#
#                       Chỉ tiêu hiệu quả hoạt động                 \
#   Vốn CSH/Vốn điều lệ           Vòng quay tài sản Vòng quay TSCĐ
# 0            1.802578                    0.168564     121.775022
# 1            1.026491                    0.156992     105.385605
# 2            0.904536                    0.204426     172.225781
# 3            0.910997                    0.296344     269.213152
# 4            0.629646                    0.221383     142.402909
#
# ...

# %% [markdown]
# #### MAS

# %%
from vnstock_data.explorer.mas import Finance
fin = Finance(symbol='VCI', period='quarter')

# %%
fin.balance_sheet(lang='vi').head()
# Out:
#     period TÀI SẢN A. TÀI SẢN NGẮN HẠN I. Tài sản tài chính ngắn hạn  \
# 0  2025-Q1    None      23620977742780                23269197505865
# 1  2024-Q4    None      26491835561026                26323154756009
# 2  2024-Q3    None      20322217963459                20188143737526
# 3  2024-Q2    None      23009916452730                22609415802879
# 4  2024-Q1    None      19458498860847                19197280192757
#
#   1. Tiền và các khoản tương đương tiền      1.1. Tiền  \
# 0                         2302263974886  2302263974886
# 1                         4743771932745  4743771932745
# 2                         2543516547760  2543516547760
# 3                         3903157759657  3888157759657
# 4                         1040594399692  1040594399692
#
#   1.2. Các khoản tương đương tiền Các khoản đầu tư tài chính ngắn hạn  \
# 0                            None                                None
# 1                            None                                None
# ...

# %%
fin.income_statement(lang='vi').head()
# Out:
#     period  \
# 0  2025-Q1
# 1  2024-Q4
# 2  2024-Q3
# 3  2024-Q2
# 4  2024-Q1
#
#   1.1. Lãi từ các tài sản tài chính ghi nhận thông qua lãi/lỗ (FVTPL)  \
# 0                                       354620858555
# 1                                       442927214370
# 2                                       535759271261
# 3                                       447623383804
# 4                                       352304951109
#
#   a. Lãi bán các tài sản tài chính  \
# 0                     353326679620
# 1                     437849136178
# 2                     533944641606
# 3                     449263881222
# 4                     338334044066
#
#   b. Chênh lệch tăng đánh giá lại các TSTC thông qua lãi/lỗ  \
# 0                                        -1339866473
# 1                                         2469489776
# 2                                         -432439523
# 3                                        -6036131450
# ...

# %%
fin.cash_flow(lang='vi').head()
# Out:
#     period 1. Lợi nhuận trước thuế 2. Điều chỉnh cho các khoản  \
# 0  2025-Q1            355107020678                 90805069295
# 1  2024-Q4                    None                        None
# 2  2024-Q3                    None                        None
# 3  2024-Q2                    None                        None
# 4  2024-Q1            227540468148                122510589993
#
#   - Khấu hao tài sản cố định - Các khoản lập dự phòng  \
# 0                 3311039364                     None
# 1                       None                     None
# 2                       None                     None
# 3                       None                     None
# 4                 2355785701                     None
#
#   - Chi phí phải trả, chi phí trả trước  \
# 0                                  None
# 1                                  None
# 2                                  None
# 3                                  None
# 4                                  None
#
# ...

# %%
fin.ratio(lang='vi').head()
# Out:
#     period Thu nhập trên mỗi cổ phần của 4 quý gần nhất (EPS)  \
# 0  2025-Q1                                               1783
# 1  2024-Q4                                               1822
# 2  2024-Q3                                               1838
# 3  2024-Q2                                               1780
# 4  2024-Q1                                               1411
#
#   Giá trị sổ sách của cổ phiếu (BVPS)  \
# 0                               17519
# 1                               18026
# 2                               15044
# 3                               20046
# 4                               18691
#
#   Chỉ số giá thị trường trên thu nhập (P/E)  \
# 0                                     21.49
# 1                                     18.22
# 2                                     19.97
# 3                                      25.9
# 4                                     38.13
#
#   Chỉ số giá thị trường trên giá trị sổ sách (P/B)  \
# ...

# %%
fin.annual_plan(lang='vi').head()
# Out:
#    period Doanh thu kế hoạch Lợi nhuận trước thuế kế hoạch  \
# 0    2025      4325000000000                 1420000000000
# 1    2024      2511000000000                  700000000000
# 2    2023      3246000000000                 1000000000000
# 3    2022      3240000000000                 1900000000000
# 4    2021      2050000000000                 1250000000000
#
#   Tỷ lệ cổ tức bằng tiền (% VĐL) kế hoạch Tỷ lệ cổ tức (%) kế hoạch
# 0                                    None                         8
# 1                                    None                         8
# 2                                    None                        15
# 3                                    None                        30
# 4                                      15                        10

# %% [markdown]
# ## 4. Trạng thái niêm yết

# %%
from vnstock_data import Listing

Listing(source='vnd').all_symbols()
# Out:
#         symbol   type exchange    status  \
# 0          ENF    IFC    UPCOM  delisted
# 1       VFMVFA    IFC     HOSE  delisted
# 2       MAFPF1    IFC     HOSE  delisted
# 3     FUCTVGF2    IFC     HOSE  delisted
# 4       ASIAGF    IFC     HOSE  delisted
# ...        ...    ...      ...       ...
# 1946       CMV  STOCK     HOSE    listed
# 1947       VIX  STOCK     HOSE    listed
# 1948       TRC  STOCK     HOSE    listed
# 1949       BCG  STOCK     HOSE    listed
# 1950       CTR  STOCK     HOSE    listed
#
#                                            company_name  \
# 0     Quỹ Đầu tư Năng động Eastspring Investments Vi...
# 1                        Quỹ Đầu tư năng động Việt Nam
# 2                       Quỹ đầu tư tăng trưởng Manulife
# 3                   Quỹ Đầu tư Tăng trưởng Thiên Việt 2
# 4                           Quỹ đầu tư tăng trưởng ACB
# ...                                                 ...
# 1946               Công ty Cổ phần Thương Nghiệp Cà Mau
# ...

# %% [markdown]
# ## 5. Top cổ phiếu

# %%
from vnstock_data import TopStock
top = TopStock()

# %% [markdown]
# ### Top tăng giá

# %%
top.gainer()
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    NVL  VNINDEX       12.25  2025-05-06 15:59             0.80
# 1    JVC  VNINDEX        4.79  2025-05-06 15:59             0.31
# 2    ITD  VNINDEX       14.00  2025-05-06 15:59             0.90
# 3    VPG  VNINDEX       12.05  2025-05-06 15:59             0.75
# 4    SGT  VNINDEX       18.05  2025-05-06 15:59             0.85
# 5    BCG  VNINDEX        3.07  2025-05-06 15:59             0.14
# 6    PAC  VNINDEX       31.60  2025-05-06 15:59             1.40
# 7    GEG  VNINDEX       15.25  2025-05-06 15:59             0.65
# 8    GIL  VNINDEX       16.00  2025-05-06 15:59             0.65
# 9    DHG  VNINDEX      103.00  2025-05-06 15:59             4.00
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0             6.986900       4.489191e+11      18547530.0
# 1             6.919643       2.453917e+09        413735.0
# 2             6.870229       2.222550e+09         43705.0
# ...

# %% [markdown]
# ### Top giảm giá

# %%
top.loser()
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    TDH  VNINDEX        4.19  2025-05-06 15:59            -0.31
# 1    RAL  VNINDEX       98.90  2025-05-06 15:59            -5.30
# 2    PTC  VNINDEX        5.80  2025-05-06 15:59            -0.29
# 3    TMT  VNINDEX       12.30  2025-05-06 15:59            -0.60
# 4    HAG  VNINDEX       12.80  2025-05-06 15:59            -0.60
# 5    CCC  VNINDEX       19.30  2025-05-06 15:59            -0.90
# 6    C47  VNINDEX        6.52  2025-05-06 15:59            -0.29
# 7    HAH  VNINDEX       63.50  2025-05-06 15:59            -2.50
# 8    VSC  VNINDEX       23.05  2025-05-06 15:59            -0.90
# 9    CIG  VNINDEX        7.90  2025-05-06 15:59            -0.26
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0            -6.888889       3.113252e+09        751700.0
# 1            -5.086372       1.106356e+10         24000.0
# 2            -4.761905       1.778000e+06         34875.0
# ...

# %% [markdown]
# ### Top theo GTGD lớn nhất

# %%
top.value()
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    SHB  VNINDEX       12.50  2025-05-06 15:59            -0.20
# 1    TCB  VNINDEX       26.85  2025-05-06 15:59             0.35
# 2    FPT  VNINDEX      109.70  2025-05-06 15:59             1.10
# 3    HPG  VNINDEX       25.45  2025-05-06 15:59            -0.25
# 4    MBB  VNINDEX       23.55  2025-05-06 15:59             0.00
# 5    NVL  VNINDEX       12.25  2025-05-06 15:59             0.80
# 6    VPB  VNINDEX       16.90  2025-05-06 15:59             0.30
# 7    VIC  VNINDEX       70.50  2025-05-06 15:59             0.50
# 8    VIX  VNINDEX       12.30  2025-05-06 15:59            -0.15
# 9    SSI  VNINDEX       23.15  2025-05-06 15:59             0.05
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0            -1.574803       6.839081e+11      80281235.0
# 1             1.320755       6.564922e+11      24031015.0
# 2             1.012891       6.260440e+11       9474185.0
# ...

# %% [markdown]
# ### Top theo KLGD

# %%
top.volume()
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    SC5  VNINDEX       17.85  2025-05-06 15:59             0.00
# 1    RAL  VNINDEX       98.90  2025-05-06 15:59            -5.30
# 2    ITD  VNINDEX       14.00  2025-05-06 15:59             0.90
# 3    SJS  VNINDEX       90.50  2025-05-06 15:59             3.20
# 4    ANV  VNINDEX       15.70  2025-05-06 15:59             0.40
# 5    PPC  VNINDEX       12.80  2025-05-06 15:59             0.30
# 6    GEG  VNINDEX       15.25  2025-05-06 15:59             0.65
# 7    VPG  VNINDEX       12.05  2025-05-06 15:59             0.75
# 8    CCC  VNINDEX       19.30  2025-05-06 15:59            -0.90
# 9    DHG  VNINDEX      103.00  2025-05-06 15:59             4.00
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0             0.000000       2.364735e+09         12220.0
# 1            -5.086372       1.106356e+10         24000.0
# 2             6.870229       2.222550e+09         43705.0
# ...

# %% [markdown]
# ### Top GD thoả thuận

# %%
top.deal()
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    SC5  VNINDEX       17.85  2025-05-06 15:59             0.00
# 1    PHC  VNINDEX        5.20  2025-05-06 15:59             0.02
# 2    CDC  VNINDEX       18.20  2025-05-06 15:59            -0.30
# 3    KOS  VNINDEX       38.60  2025-05-06 15:59            -0.05
# 4    NT2  VNINDEX       18.15  2025-05-06 15:59            -0.15
# 5    SHI  VNINDEX       14.45  2025-05-06 15:59            -0.05
# 6    OCB  VNINDEX       10.45  2025-05-06 15:59             0.05
# 7    FRT  VNINDEX      171.80  2025-05-06 15:59            -0.70
# 8    DC4  VNINDEX       12.80  2025-05-06 15:59            -0.30
# 9    GEX  VNINDEX       28.60  2025-05-06 15:59             0.25
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0             0.000000       2.364735e+09         12220.0
# 1             0.386100       6.327400e+08         80125.0
# 2            -1.621622       6.528150e+08         57975.0
# ...

# %% [markdown]
# ### Top NĐTNN mua ròng

# %%
top.foreign_buy(date='2024-08-16')
# Out:
#   symbol        date     net_value
# 0    MWG  2024-08-16  1.015998e+11
# 1    CTG  2024-08-16  6.709855e+10
# 2    DIG  2024-08-16  6.705117e+10
# 3    MSN  2024-08-16  6.318864e+10
# 4    VCI  2024-08-16  5.041683e+10
# 5    VND  2024-08-16  3.089996e+10
# 6    NVL  2024-08-16  3.054193e+10
# 7    DPM  2024-08-16  2.839805e+10
# 8    DGC  2024-08-16  2.769208e+10
# 9    FPT  2024-08-16  2.629880e+10

# %% [markdown]
# ### Top NĐTNN bán ròng

# %%
top.foreign_sell(date='2024-08-16')
# Out:
#      symbol        date     net_value
# 0       VHM  2024-08-16 -3.136147e+11
# 1       HPG  2024-08-16 -1.804457e+11
# 2       TCB  2024-08-16 -1.083005e+11
# 3       HSG  2024-08-16 -5.660693e+10
# 4       VPB  2024-08-16 -4.944804e+10
# 5  FUEVFVND  2024-08-16 -3.769779e+10
# 6       FRT  2024-08-16 -3.130877e+10
# 7       HDB  2024-08-16 -2.534124e+10
# 8       QNS  2024-08-16 -1.809028e+10
# 9       NLG  2024-08-16 -1.657578e+10

# %% [markdown]
# ## 6. Giá hàng hoá

# %%
from vnstock_data import CommodityPrice

# Khởi tạo đối tượng CommodityPrice với ngày mặc định
commodity = CommodityPrice(start="2022-01-03", end="2024-12-31")

# Lấy dữ liệu giá vàng
gold_vn = commodity.gold_vn()  # Giá vàng Việt Nam (mua vào)
print("Gold VN:\n", gold_vn)

gold_global = commodity.gold_global()  # Giá vàng thế giới
print("Gold Global:\n", gold_global)

# Lấy dữ liệu giá xăng
gas_vn = commodity.gas_vn()  # Giá xăng RON92
print("Gas VN:\n", gas_vn)

oil_crude = commodity.oil_crude()  # Giá dầu thô
print("Oil Crude:\n", oil_crude)

# Lấy dữ liệu khí thiên nhiên
gas_natural = commodity.gas_natural()  # Giá khí thiên nhiên
print("Gas Natural:\n", gas_natural)

# Lấy dữ liệu giá than
coke = commodity.coke()  # Giá than cốc
print("Coke:\n", coke)

# Lấy dữ liệu giá thép
steel_d10 = commodity.steel_d10()  # Giá thép D10
print("Steel D10:\n", steel_d10)

steel_hrc = commodity.steel_hrc()  # Giá thép HRC
print("Steel HRC:\n", steel_hrc)

# Lấy dữ liệu giá quặng sắt
iron_ore = commodity.iron_ore()  # Giá quặng sắt
print("Iron Ore:\n", iron_ore)

# Lấy dữ liệu giá phân bón
fertilizer_ure = commodity.fertilizer_ure()  # Giá phân ure
print("Fertilizer URE:\n", fertilizer_ure)

# Lấy dữ liệu giá nông sản
soybean = commodity.soybean()  # Giá đậu tương
print("Soybean:\n", soybean)

corn = commodity.corn()  # Giá ngô (bắp)
print("Corn:\n", corn)

sugar = commodity.sugar()  # Giá đường
print("Sugar:\n", sugar)

# Lấy dữ liệu giá heo hơi
pork_north_vn = commodity.pork_north_vn()  # Giá heo hơi miền Bắc Việt Nam
print("Pork North VN:\n", pork_north_vn)

pork_china = commodity.pork_china()  # Giá heo hơi Trung Quốc
print("Pork China:\n", pork_china)
# Out:
# Gold VN:
#                  buy     sell
# time
# 2022-01-03  60900.0  61600.0
# 2022-01-04  61000.0  61700.0
# 2022-01-05  60750.0  61450.0
# 2022-01-06  60900.0  61600.0
# 2022-01-09  60900.0  61650.0
# ...             ...      ...
# 2024-12-25  82300.0  84300.0
# 2024-12-26  82500.0  84500.0
# 2024-12-27  82700.0  84700.0
# 2024-12-28  82700.0  84700.0
# 2024-12-30  82500.0  84500.0
#
# [791 rows x 2 columns]
# Gold Global:
#                open    high     low   close    volume
# time
# 2022-01-03  1830.1  1833.0  1798.2  1800.1  168305.0
# 2022-01-04  1801.1  1817.2  1798.1  1814.6  167708.0
# 2022-01-05  1815.2  1830.7  1808.2  1825.1  173344.0
# 2022-01-06  1810.6  1811.6  1785.4  1789.2  238644.0
# 2022-01-07  1791.0  1798.4  1781.3  1797.4  238931.0
# ...            ...     ...     ...     ...       ...
# 2024-12-23  2639.1  2646.8  2623.2  2628.2  100814.0
# 2024-12-24  2629.4  2635.8  2624.2  2635.5   52221.0
# 2024-12-26  2638.0  2655.7  2634.1  2653.9   77712.0
# ...

# %% [markdown]
# ## 7. Định giá thị trường

# %%
from vnstock_data import Market

market = Market(index='HNXINDEX')

# %%
market.pe(duration='5Y')
# Out:
#                    pe
# reportDate
# 2020-05-07   9.440225
# 2020-05-08   9.539828
# 2020-05-11   9.665722
# 2020-05-12   9.668673
# 2020-05-13   9.684979
# ...               ...
# 2025-04-24  19.998920
# 2025-04-25  20.127069
# 2025-04-28  20.066628
# 2025-04-29  20.084770
# 2025-05-05  20.574198
#
# [1242 rows x 1 columns]

# %%
market.pb(duration='5Y')
# Out:
#                   pb
# reportDate
# 2020-05-07  0.989990
# 2020-05-08  1.001150
# 2020-05-11  1.014459
# 2020-05-12  1.014834
# 2020-05-13  1.016593
# ...              ...
# 2025-04-24  1.440725
# 2025-04-25  1.440668
# 2025-04-28  1.437954
# 2025-04-29  1.443219
# 2025-05-05  1.431920
#
# [1242 rows x 1 columns]

# %%
market.evaluation(duration='5M')
# Out:
#                    pe        pb
# reportDate
# 2024-12-09  16.204109  1.441480
# 2024-12-10  16.261061  1.446544
# 2024-12-11  16.250641  1.445596
# 2024-12-12  16.249636  1.444474
# 2024-12-13  16.162374  1.436755
# ...               ...       ...
# 2025-04-24  19.998920  1.440725
# 2025-04-25  20.127069  1.440668
# 2025-04-28  20.066628  1.437954
# 2025-04-29  20.084770  1.443219
# 2025-05-05  20.574198  1.431920
#
# [96 rows x 2 columns]
